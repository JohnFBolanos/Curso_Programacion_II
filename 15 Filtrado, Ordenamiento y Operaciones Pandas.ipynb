# %% [markdown]
# ## 🎯 **Objetivos Ampliados**
#
# - Transformar y preparar datos para análisis
# - Aplicar operaciones avanzadas de filtrado y ordenamiento
# - Dominar técnicas de limpieza de datos
# - Crear y transformar columnas eficientemente

# %% [markdown]
# ## 📱  Uso de una Aplicación Tecnológica
#
# El siguiente conjunto de datos simula información recolectada de **100 usuarios** de una aplicación tecnológica (por ejemplo, una *app de aprendizaje en línea* o una *plataforma de productividad personal*).
# Los registros contienen variables demográficas y de comportamiento de uso, útiles para realizar análisis exploratorios, segmentación de usuarios y estudios de satisfacción.
#
# ---
#
# ### 🧾 Descripción general
# Cada fila del DataFrame representa un usuario único, e incluye información sobre:
# - Su edad y país de residencia.
# - Su nivel de interacción con la aplicación (tiempo y sesiones).
# - Su nivel de satisfacción reportado con la experiencia de uso.
#
# ---
#
# ### 📚 Diccionario de variables
#
# | Variable | Tipo de dato | Descripción |
# |-----------|---------------|-------------|
# | `Usuario` | *string* | Identificador único del usuario (ej. `user_001`) |
# | `Edad` | *int* | Edad del usuario en años |
# | `País` | *string* | País de residencia del usuario (ej. Colombia, México, España) |
# | `Tiempo_uso_min` | *int* | Tiempo promedio de uso diario de la aplicación (en minutos) |
# | `Sesiones_dia` | *int* | Número promedio de sesiones abiertas por día |
# | `Satisfacción` | *string* | Nivel de satisfacción del usuario con la aplicación (`Bajo`, `Medio`, `Alto`) |
#
# ---

# %%
import pandas as pd
import numpy as np

# Semilla para reproducibilidad
np.random.seed(123)

# Número de registros
n = 100

# Variables simuladas
usuarios = [f"user_{i:03d}" for i in range(1, n+1)]
edades = np.random.randint(18, 50, size=n)
pais = np.random.choice(["Colombia", "México", "Argentina", "Chile", "Perú", "España"], size=n)
tiempo_uso_min = np.random.randint(5, 240, size=n)              # minutos diarios de uso
sesiones = np.random.randint(1, 10, size=n)                     # sesiones por día
nivel_satisfaccion = np.random.choice(["Bajo", "Medio", "Alto"], size=n, p=[0.2, 0.5, 0.3])

# Crear DataFrame
df = pd.DataFrame({
    "Usuario": usuarios,
    "Edad": edades,
    "País": pais,
    "Tiempo_uso_min": tiempo_uso_min,
    "Sesiones_dia": sesiones,
    "Satisfacción": nivel_satisfaccion
})

# Mostrar primeras filas
df.head()
# Out:
#     Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 0  user_001    48     México             106             4        Medio
# 1  user_002    31       Perú             135             4        Medio
# 2  user_003    48  Argentina             151             2         Bajo
# 3  user_004    20     México              51             8         Alto
# 4  user_005    46     México              50             9        Medio

# %%
df.shape
# Out:
# (100, 6)

# %% [markdown]
# ## 1️⃣ Filtrado de datos
#
# Permite seleccionar filas que cumplan ciertas condiciones.

# %%
# Ejemplo: Filtrar mayores de 45 años
df1=df[df['Edad'] > 45]
df1.shape
# Out:
# (12, 6)

# %%
df['Edad'] > 45
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Edad, Length: 100, dtype: bool

# %%
# Filtrar por varias condiciones
df[(df['Edad'] > 45) & (df['País'] == 'México')]
# Out:
#      Usuario  Edad    País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 0   user_001    48  México             106             4        Medio
# 4   user_005    46  México              50             9        Medio
# 46  user_047    46  México             199             2         Alto

# %%
# Usuarios de Colombia o México con satisfacción “Medio”
df2=df[(df["País"].isin(["Colombia", "México"])) & (df["Satisfacción"] == "Medio")]
df2.shape
# Out:
# (20, 6)

# %%
# Usuarios de Colombia o México con satisfacción “Medio”
df3=df[ (( df["País"]=="Colombia" ) | (df["País"]=="México")) & (df["Satisfacción"] == "Medio")]
df3.shape
# Out:
# (20, 6)

# %% [markdown]
# ## Ejercicio 1
#
# ¿Cuántas personas son de Perú, no tienen satisfacción alta y sus sesiones por día son exactamente 3? Rta: user_089

# %%
# Solución ejercicio 1
df[(df["Satisfacción"]!="Alto") & (df["País"]=="Perú") &(df["Sesiones_dia"]==3)]["Edad"]
# Out:
# 88    29
# Name: Edad, dtype: int64

# %% [markdown]
# ## 2️⃣ Ordenamiento
#
# Ordenar por tiempo de uso (de mayor a menor)

# %%
df.sort_values("Tiempo_uso_min", ascending=False).head(10)
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 92  user_093    29   Colombia             238             1         Alto
# 95  user_096    41     México             237             1         Bajo
# 47  user_048    46   Colombia             234             6        Medio
# 56  user_057    19       Perú             233             8         Alto
# 84  user_085    32  Argentina             230             6        Medio
# 75  user_076    30     España             229             8        Medio
# 87  user_088    25     España             225             4        Medio
# 61  user_062    23   Colombia             224             3         Bajo
# 8   user_009    37     México             224             8        Medio
# 94  user_095    23      Chile             220             8        Medio

# %% [markdown]
# Ordenar por país y dentro de cada país por edad

# %%
df.sort_values(["País", "Edad"], ascending=[True, True]).head(20)
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 19  user_020    18  Argentina             143             1        Medio
# 84  user_085    32  Argentina             230             6        Medio
# 80  user_081    37  Argentina              70             2        Medio
# 32  user_033    41  Argentina             211             7         Alto
# 99  user_100    42  Argentina             169             6        Medio
# 73  user_074    45  Argentina              15             7        Medio
# 74  user_075    47  Argentina             141             5         Alto
# 2   user_003    48  Argentina             151             2         Bajo
# 14  user_015    18      Chile             200             1        Medio
# 21  user_022    18      Chile              50             2         Alto
# 13  user_014    19      Chile              67             2         Bajo
# 5   user_006    20      Chile             190             6        Medio
# ...

# %% [markdown]
# ### Ejercicio 2:
#
# Ordena los usuarios primero por nivel de satisfacción (Ascendente) y luego por sesiones diarias (Descendente) y por ultimo la edad (Ascendente).

# %%
# Solución 2
df.sort_values(["Satisfacción", "Sesiones_dia", "Edad"], ascending=[True, False,True]).head(10)
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 29  user_030    34      Chile             115             9         Alto
# 56  user_057    19       Perú             233             8         Alto
# 3   user_004    20     México              51             8         Alto
# 24  user_025    37   Colombia             192             8         Alto
# 38  user_039    38   Colombia              92             8         Alto
# 27  user_028    22     México              32             7         Alto
# 68  user_069    31   Colombia             158             7         Alto
# 32  user_033    41  Argentina             211             7         Alto
# 63  user_064    29       Perú              39             6         Alto
# 30  user_031    22     México               8             5         Alto

# %%
df.head(3)
# Out:
#     Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 0  user_001    48     México             106             4        Medio
# 1  user_002    31       Perú             135             4        Medio
# 2  user_003    48  Argentina             151             2         Bajo

# %% [markdown]
# ##  3️⃣ Creación y eliminación de columnas y filas

# %%
df["PAIS"]=df["País"].str.upper()
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#          PAIS
# 0      MÉXICO
# 1        PERÚ
# 2   ARGENTINA
# 3      MÉXICO
# ...

# %% [markdown]
# ### Ejerccio 3:
#
# crear una nueva colunma que represente el tiempo de uso minimo por el numero de seriones al día

# %%
# Solucion ejercicio 3
df["Tiempo_X_Sesion"]=df["Tiempo_uso_min"]*df["Sesiones_dia"]
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#          PAIS  Tiempo_X_Sesion
# 0      MÉXICO              424
# ...

# %%
# Elinimar una colunma:
df=df.drop(columns="PAIS")
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#     Tiempo_X_Sesion
# 0               424
# 1               540
# 2               302
# ...

# %%
# Agregar una nueva fila con loc
df.loc[-1] = ["user000",34,'Chile', 35, 666, 'Medio',1111]
df
# Out:
#       Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
#  0   user_001    48     México             106             4        Medio
#  1   user_002    31       Perú             135             4        Medio
#  2   user_003    48  Argentina             151             2         Bajo
#  3   user_004    20     México              51             8         Alto
#  4   user_005    46     México              50             9        Medio
# ..        ...   ...        ...             ...           ...          ...
#  96  user_097    43   Colombia             154             4        Medio
#  97  user_098    36     España              94             8         Bajo
#  98  user_099    38     México              55             1         Bajo
#  99  user_100    42  Argentina             169             6        Medio
# -1    user000    34      Chile              35           666        Medio
#
#      Tiempo_X_Sesion
#  0               424
#  1               540
# ...

# %%
# Eliminar una fila o un registro
df=df.drop(-1)
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#     Tiempo_X_Sesion
# 0               424
# 1               540
# 2               302
# ...

# %% [markdown]
# # Modificación de un dato

# %%
# Ubircar por indexacción
df.iloc[3, 2] = 'Perú'
df
# Out:
#       Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
#  0   user_001    48     México             106             4        Medio
#  1   user_002    31       Perú             135             4        Medio
#  2   user_003    48  Argentina             151             2         Bajo
#  3   user_004    20       Perú              51             8         Alto
#  4   user_005    46     México              50             9        Medio
# ..        ...   ...        ...             ...           ...          ...
#  96  user_097    43   Colombia             154             4        Medio
#  97  user_098    36     España              94             8         Bajo
#  98  user_099    38     México              55             1         Bajo
#  99  user_100    42  Argentina             169             6        Medio
# -1    user000    34      Chile              35           666        Medio
#
#      Tiempo_X_Sesion
#  0               424
#  1               540
# ...

# %%
# Ubicar por variable
df.loc[df['Usuario'] == 'user_003', 'País'] = 'Chile'
df
# Out:
#       Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
#  0   user_001    48     México             106             4        Medio
#  1   user_002    31       Perú             135             4        Medio
#  2   user_003    48      Chile             151             2         Bajo
#  3   user_004    20       Perú              51             8         Alto
#  4   user_005    46     México              50             9        Medio
# ..        ...   ...        ...             ...           ...          ...
#  96  user_097    43   Colombia             154             4        Medio
#  97  user_098    36     España              94             8         Bajo
#  98  user_099    38     México              55             1         Bajo
#  99  user_100    42  Argentina             169             6        Medio
# -1    user000    34      Chile              35           666        Medio
#
#      Tiempo_X_Sesion
#  0               424
#  1               540
# ...

# %% [markdown]
# ### 4️⃣  map() y apply() en Pandas
#
# #### 🔹  `map()`
#
# 👉 Se usa sobre **una sola columna (Serie)**.
# Sirve para **reemplazar o transformar valores individuales** de forma rápida.

# %%
# Diccionario de mapeo
mapeo = {"Bajo": 1, "Medio": 2, "Alto": 3}

df["Satisfacción_num"] = df["Satisfacción"].map(mapeo)
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#     Tiempo_X_Sesion  Satisfacción_num
# 0               424                 2
# ...

# %%
# Función simple para clasificar edad
def clasificar_edad(edad):
    if edad < 25:
        return "Joven"
    elif edad < 35:
        return "Adulto"
    else:
        return "Maduro"

# Aplicar map con función

df['Grupo_edad'] = df['Edad'].map(clasificar_edad)
df.head()
# Out:
#     Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0  user_001    48     México             106             4        Medio
# 1  user_002    31       Perú             135             4        Medio
# 2  user_003    48  Argentina             151             2         Bajo
# 3  user_004    20     México              51             8         Alto
# 4  user_005    46     México              50             9        Medio
#
#    Tiempo_X_Sesion  Satisfacción_num Grupo_edad
# 0              424                 2     Maduro
# 1              540                 2     Adulto
# 2              302                 1     Maduro
# 3              408                 3      Joven
# 4              450                 2     Maduro

# %% [markdown]
# ### Ejercicios 4: Crear una nueva variable con `map()` y `lambda`
#
# Crea una nueva columna llamada **`N_Usuario`** que tome los valores de la columna **`Usuario`** (por ejemplo `"user_023"`) y extraiga **solo la parte numérica** usando el método `map()`  junto con una **función anónima (`lambda`)**.

# %%
df["N_Usuario"]=df["Usuario"].map(lambda x : int(x[-3:]))
df
# Out:
#      Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0   user_001    48     México             106             4        Medio
# 1   user_002    31       Perú             135             4        Medio
# 2   user_003    48  Argentina             151             2         Bajo
# 3   user_004    20     México              51             8         Alto
# 4   user_005    46     México              50             9        Medio
# ..       ...   ...        ...             ...           ...          ...
# 95  user_096    41     México             237             1         Bajo
# 96  user_097    43   Colombia             154             4        Medio
# 97  user_098    36     España              94             8         Bajo
# 98  user_099    38     México              55             1         Bajo
# 99  user_100    42  Argentina             169             6        Medio
#
#     Tiempo_X_Sesion  Satisfacción_num Grupo_edad  N_Usuario
# ...

# %% [markdown]
# 🔹 2️⃣ apply()
#
# 👉 Se usa sobre columnas completas o filas completas.
# Permite aplicar funciones más complejas, incluso que involucren varias columnas.

# %%
def clasificar_usuario(fila):
    if fila["Tiempo_uso_min"] > 180 and fila["Satisfacción"] == "Alto":
        return "Usuario Premium"
    elif fila["Tiempo_uso_min"] < 60:
        return "Usuario Ocasional"
    else:
        return "Usuario Regular"

df["Tipo_usuario"] = df.apply(clasificar_usuario, axis=1)
df.head()
# Out:
#     Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción  \
# 0  user_001    48     México             106             4        Medio
# 1  user_002    31       Perú             135             4        Medio
# 2  user_003    48  Argentina             151             2         Bajo
# 3  user_004    20     México              51             8         Alto
# 4  user_005    46     México              50             9        Medio
#
#    Tiempo_X_Sesion  Satisfacción_num Grupo_edad  N_Usuario       Tipo_usuario
# 0              424                 2     Maduro          1    Usuario Regular
# 1              540                 2     Adulto          2    Usuario Regular
# 2              302                 1     Maduro          3    Usuario Regular
# 3              408                 3      Joven          4  Usuario Ocasional
# 4              450                 2     Maduro          5  Usuario Ocasional

# %% [markdown]
# #  Taller:
#
# Usa el DataFrame `df` definido en clase (con las columnas `Usuario`, `Edad`, `País`, `Tiempo_uso_min`, `Sesiones_dia`, `Satisfacción`).
#
# ## 1) Ejercicio de Filtrado
#
# Halla la cantidad de personas que cumplen las siguientes condiciones:
#
# a) Son de México y su tiempo de uso mínimo es menor o igual a 70 minutos.
#
# b) Son menores de 60 años pero mayores o iguales a 40, y tienen satisfacción alta.
#
# c) No son de Argentina ni de España y sus sesiones diarias son de 3, 4, 5 o 6.
#
# d) Indica en qué país vive la persona que tiene 42 años, 8 sesiones al día y una satisfacción media.
#
#
#
#
# ## 2) Clasificar sesiones con una función y `apply()`
#
# ### Enunciado
# Crea una función llamada **`clasificar_sesiones`** que reciba el número de sesiones y retorne:
# - `"Pocas sesiones"` si tiene **2 o menos** sesiones
# - `"Sesiones normales"` si tiene **entre 3 y 5** sesiones
# - `"Muchas sesiones"` si tiene **más de 5** sesiones
#
# Aplica esta función a la columna `Sesiones_dia` usando `apply()` y guarda el resultado en una nueva columna llamada **`Categoria_sesiones`**.
#
#
# ## 3) Crear perfil de usuario por fila con `apply(axis=1)`
#
#
# Crea una función llamada **`crear_perfil`** que reciba una **fila completa** del DataFrame y retorne un string que describa el perfil del usuario según las siguientes reglas:
#
# **Edad:**
# - Menor de 25 → agregar `"Joven"`
# - Mayor de 40 → agregar `"Experimentado"`
#
# **Tiempo de uso:**
# - Más de 120 minutos diarios → agregar `"Gran consumidor"`
#
# **Satisfacción:**
# - `"Alto"` → agregar `"Satisfecho"`
# - `"Bajo"` → agregar `"Insatisfecho"`
#
# Si no aplica ninguna característica especial, retornar `"Usuario promedio"`.
#
# Aplica esta función al DataFrame usando `apply()` con `axis=1` y guarda el resultado en una nueva columna llamada **`Perfil_usuario`**.
