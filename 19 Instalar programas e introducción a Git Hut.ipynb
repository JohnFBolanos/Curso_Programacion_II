# %% [markdown]
# # 🧩 Cuaderno de Instalación de Programas
#
# En este cuaderno se explican **paso a paso** los procedimientos para instalar y configurar las herramientas necesarias para trabajar con **Git** y **GitHub** de forma profesional y colaborativa.
#
# El objetivo es que al finalizar puedas:
#
# - Instalar correctamente **Git**, **Visual Studio Code** y **Python**.
# - Verificar que las herramientas estén integradas entre sí.
# - Preparar tu equipo para **crear repositorios**, **usar control de versiones** y **colaborar en proyectos** con otros desarrolladores.
#
# ## 🔧 Programas a instalar
#
# 1. **Git** – sistema de control de versiones.
# 2. **Visual Studio Code (VS Code)** – editor de código recomendado.
# 3. **Python** (versión 3.12 ).
#
# > ⚠️ Nota: se recomienda usar **Python 3.12**, ya que las versiones más recientes (como 3.14) pueden presentar incompatibilidades con algunas librerías o entornos de trabajo.
#
# ---

# %% [markdown]
# ## Paso 1) Crear una cuenta en GitHub
#
# 1. Ingresa a [GitHub.com](https://github.com) y haz clic en **Sign up**.
# 2. Regístrate usando tu **correo de Gmail** (recomendado para facilitar la recuperación y autenticación).
# 3. Elige un **nombre de usuario** profesional o académico (por ejemplo: `juanperez-data` o `maria-analitica`).
# 4. Crea una **contraseña segura** y recuerda guardarla, ya que será necesaria durante la configuración de Git y VS Code.
# 5. Completa el proceso de verificación y confirma tu cuenta desde el correo electrónico que GitHub enviará.

# %% [markdown]
# ## Paso 2) Instalar Git
#
# 1. Ingresa a la página oficial de descargas de Git:
#    👉 [https://git-scm.com/downloads/win](https://git-scm.com/downloads/win)
#
# 2. El instalador detectará automáticamente tu sistema operativo (Windows).
#    Haz clic en **“Download for Windows”** y ejecuta el archivo descargado.
#
# 3. Durante la instalación, se recomienda **mantener las opciones por defecto**, salvo las siguientes:
#    - En la ventana donde se pregunta si deseas crear accesos directos, selecciona ✅ **“Add icon on the Desktop”**.
# ![image.png](data:image/png;base64,...)
#
#    - En la ventana **“Override the default branch name for new repositories”**, marca la opción
#      👉 **“main”** (para que tus repositorios usen `main` en lugar de `master` como rama principal).
#
#      ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Continúa presionando **Next** en las demás ventanas hasta finalizar la instalación.
#
# 5. Al terminar, abre **Git Bash** desde el menú inicio o el escritorio para comprobar que todo está correcto:
#    ```bash
#    git --version

# %% [markdown]
# ## Paso 3) Instalar Visual Studio Code (VS Code)
#
# 1. Ingresa a la página oficial de descargas de VS Code:
#    👉 [https://code.visualstudio.com/docs/?dv=win64user](https://code.visualstudio.com/docs/?dv=win64user)
#
# 2. El instalador se descargará automáticamente.
#    Una vez descargado, ejecútalo para iniciar la instalación.
#
# 3. Durante el proceso de instalación:
#    - Acepta los términos de licencia.
#    - Marca la opción ✅ **“Add icon to the Desktop”** para crear un acceso directo.
#    - Luego haz clic en **Next** en todas las ventanas hasta llegar a **Install**.
#
# 4. Una vez finalizada la instalación, abre VS Code desde el acceso directo del escritorio o desde el menú inicio.
#
# 5. Verifica que se abrió correctamente y que aparece la pantalla de bienvenida de Visual Studio Code.
#
# 6. En la barra lateral izquierda, haz clic en el ícono de **Extensiones**
#    (parece un cuadrado formado por cuatro bloques pequeños).
#    > 💡 También puedes abrirlo rápidamente con el atajo de teclado:
#    **Ctrl + Shift + X**
#
# 7. En la barra de búsqueda superior escribe: `Python`
#
# 8. Selecciona la extensión oficial de **Microsoft** llamada **Python**
# (debe mostrar el ícono azul con una serpiente amarilla y azul).
#
# ![image.png](data:image/png;base64,...)
#
# 9. Haz clic en el botón **Install** (Instalar) y espera unos segundos.

# %% [markdown]
# ## 🐍 Paso 4) Instalar Python 3.12
#
# 1. Ingresa al sitio oficial de descargas de Python:
#    👉 [https://www.python.org/downloads/release/python-31210/](https://www.python.org/downloads/release/python-31210/)
#
# 2. Desplázate hacia abajo hasta la sección **Files** y descarga el instalador para tu sistema operativo:
#    - Si usas **Windows 64 bits**, haz clic en **Windows installer (64-bit)**.
#
# 3. Ejecuta el instalador descargado y asegúrate de marcar **Add Python to PATH** (esto permite ejecutar Python desde cualquier ventana del sistema).
#
# ![image.png](data:image/png;base64,...)
#
# 4. Deja las demás opciones por defecto y haz clic en **Install Now**.

# %% [markdown]
# ## 🧾 Paso 5) Verificar que todo quedó instalado correctamente
#
# Una vez hayas instalado **Git**, **Python 3.12** y **Visual Studio Code**, es importante comprobar que todo funciona bien.
#
# ### 🧪 1. Verificar Git
# 1. Abre el programa **Git Bash** .
# 2. Escribe el siguiente comando y presiona **Enter**:
# ```bash
# git --version
# ```
#
# Si todo está bien, verás un mensaje similar a:
# ```bash
# git version 2.51.
# ```
# ✅ Esto confirma que Git se instaló correctamente.
#
# ### 🐍 2. Verificar Python
#
# Desde la misma ventana de Git Bash, escribe:
# ```bash
# python --version
# ```
#
# Si todo está bien, verás un mensaje similar a:
# ```bash
# Python 3.12.10
# ```
#
# ✅ Esto confirma que Python 3.12 está correctamente instalado y agregado al PATH.
#
#
# ### 💻 3. Verificar Visual Studio Code
#
# En la misma ventna de Git Bash, escribe el siguiente comando:
# ```bash
# code .
# ```
# Si VS Code se abre automáticamente, significa que el programa también está bien configurado en tu sistema.
#
#
# 💡 Consejo: si alguno de los comandos anteriores no funciona, revisa que hayas marcado la opción “Add to PATH” durante la instalación o reinicia el computador para actualizar las variables de entorno.

# %% [markdown]
# # 🧩 Actividad práctica: Comandos básicos de Git y terminal
#
# 🎯 **Objetivo:**
# Familiarizarte con los comandos más usados en Git y la terminal, comprendiendo **qué hace cada uno** y **para qué sirve** dentro del flujo de trabajo mostrado en el video.
#
# 📺 **Video recomendado:** [Introducción a Git y GitHub (Fazt)](https://www.youtube.com/watch?v=mBYSUUnMt9M)
#
# ✏️ **Instrucciones:**
# 1. Observa el video con atención.
# 2. A medida que aparezcan los comandos, escríbelos en la tabla y explica con tus palabras **qué hace o para qué sirve** cada uno.
# 3. Si hace falta un comando agregarlo al final de cada tabla.
# 4. Realizar la configuración con su nombre y correo como lo muesra el video.
#
#
# ---
#
# ## 🧱 Comandos del sistema
#
# | Nº | Comando | ¿Qué hace o para qué sirve? |
# |----|----------|-----------------------------|
# | 1 | `cd` | Me permite entrar a una carpeta o cambiar de directorio. |
# | 2 | `mkdir` | |
# | 3 | `ls` | |
# | 4 | `cd ..` | |
# | 5 | `rmdir` | |
# | 6 | `clear` | |

# %% [markdown]
# ---
#
# ## 🧩 Comandos de Git
#
# | Nº | Comando | ¿Qué hace o para qué sirve? |
# |----|----------|-----------------------------|
# | 7 | `git config` | |
# | 8 | `git init` | |
# | 9 | `git status` | |
# | 10 | `git add` | |
# | 11 | `git rm --cached` | |
# | 12 | `git commit -m` | |
# | 13 | `git log` | |
# | 14 | `git add .` | |
# | 15 | `git commit -- amend` | |
# | 16 | `git reset --soft HEAD~1` | |
#
# ---

# %% [markdown]
# ## 🌿 Comandos de Git asociados a ramas (branch)
#
# | Nº | Comando | ¿Qué hace o para qué sirve? |
# |----|----------|-----------------------------|
# | 1 | `git branch` | |
# | 2 | `git checkout` | |
# | 3 | `git checkout -b` | |
# | 4 | `git branch -m` | |
# | 5 | `git branch -d` | |
# | 6 | `git log --oneline` | |
# | 7 | `git log -p` | |
# | 8 | `git merge` | |
# | 9 | `git merge --continue` | |

# %% [markdown]
# en el video hora: 3 y minuto: 24
# ## 🌐 Comandos de Git para clonar y trabajar con repositorios remotos
#
# | Nº | Comando | ¿Qué hace o para qué sirve? |
# |----|----------|-----------------------------|
# | 1 | `git clone` | |
# | 2 | `origin` | |
# | 3 | `git remote` | |
# | 4 | `git remote -v` | |
# | 5 | `git push` | |
# | 6 | `git pull` | |
# | 7 | `git fetch` | |
# | 8 | `git checkout origin/main` | |
# | 9 | `git remote add origin` | |
# | 10 | `git pull origin` | |
# | 11 | `git branch -a` | |
