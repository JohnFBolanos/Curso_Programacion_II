# %% [markdown]
# # Introducción a Pandas - Series y DataFrames
#
# ### 🎯 Objetivo general
# Comprender la estructura y funcionamiento de las principales estructuras de datos de Pandas (**Series** y **DataFrames**) y aprender a explorarlas mediante sus métodos fundamentales.
#
# ---
#
# ## 🧠 Motivación: ¿Por qué Pandas en Ciencia de Datos?
#
# En Ciencia de Datos, el 80% del tiempo se dedica a **limpiar, explorar y preparar datos**.
# Pandas es la herramienta base para:
# - Leer y transformar archivos (CSV, Excel, JSON, SQL, etc.)
# - Manipular información estructurada de forma eficiente
# - Integrarse con *NumPy*, *Matplotlib* y *Scikit-learn*
#
# 📊 **Ejemplo real:**
# Antes de crear un modelo de predicción de precios de vivienda, debemos entender cómo están organizadas las columnas, si hay valores faltantes y cómo se distribuyen las variables.
# Todo esto se logra con **Pandas**.
#
# ---

# %% [markdown]
# ### 1. Importación de la libreria
#
# ```python
#
# import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# ### 2. Creación de Series
#
# Una **Serie** es una estructura unidimensional (como una lista con etiquetas).

# %%
import pandas as pd

# Crear una Serie
numeros = pd.Series([10, 20, 30, 40])
print(numeros)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Serie con índice personalizado
edades = pd.Series([23.1, 45, 31], index=['Ana', 'Luis', 'Sofía'])
print(edades)
# Out:
# Ana      23.1
# Luis     45.0
# Sofía    31.0
# dtype: float64

# %% [markdown]
# ##  Las Series en Pandas como instancias de una clase (POO)
#
# En **Pandas**, una **Serie** es un **objeto** creado a partir de la clase `pandas.Series`.
# Esto significa que, al igual que los objetos en Programación Orientada a Objetos (POO),
# las Series tienen **atributos** (propiedades) y **métodos** (acciones que pueden realizar).
#
# **Atributos**:
#
# + `numeros.values`: array con los valores
# + `numeros.index`: etiquetas o índices
# + `numeros.dtype`: tipo de datos
#
# **Métodos**:
# + `numeros.mean()`: promedio
# + `numeros.sum()`:  suma total
# + `numeros.head(2)`:  primeras posiciones

# %%
#print("Valores:", edades.values)
print("Índices:", edades.index)
print("Tipo de datos:", edades.dtype)
print("Promedio de los datos:", edades.mean())
print("Suma de datos:", edades.sum())
print("Las primeras filas de datos:\n",edades.head())
# Out:
# Índices: Index(['Ana', 'Luis', 'Sofía'], dtype='object')
# Tipo de datos: float64
# Promedio de los datos: 33.03333333333333
# Suma de datos: 99.1
# Las primeras filas de datos:
#  Ana      23.1
# Luis     45.0
# Sofía    31.0
# dtype: float64

# %% [markdown]
# ### 3. Creación de DataFrames
#
# Un DataFrame está compuesto de Series:
#
# Cada columna de un DataFrame es, en esencia, una Serie de pandas.

# %%
# Crear Series individuales
serie_productos = pd.Series(['Laptop', 'Mouse', 'Teclado'])
serie_precios = pd.Series([999.9, 25.50, 75.00])
serie_stock = pd.Series([10, 50, 30])

# Combinarlas en un DataFrame
df_inventario = pd.DataFrame({
    'Producto': serie_productos,
    'Precio': serie_precios,
    'Stock': serie_stock
})
df_inventario
# Out:
#   Producto  Precio  Stock
# 0   Laptop   999.9     10
# 1    Mouse    25.5     50
# 2  Teclado    75.0     30

# %% [markdown]
# Un **DataFrame** es una tabla con filas y columnas (similar a Excel o SQL).

# %%
datos = {
    'Nombre': ['Ana', 'Luis', 'Sofía', "Jose"],
    'Edad': [23, 45, 31, 27],
    'Ciudad': ['Bogotá', 'Medellín', 'Cali', "Pasto"]
}

df = pd.DataFrame(datos)
df = pd.DataFrame(datos, index=[2,5,8,9])
df
# Out:
#   Nombre  Edad    Ciudad
# 2    Ana    23    Bogotá
# 5   Luis    45  Medellín
# 8  Sofía    31      Cali
# 9   Jose    27     Pasto

# %%
# Columnas y filas
print(df.columns)
print(df.index)
print(df.shape)
# Out:
# Index(['Nombre', 'Edad', 'Ciudad'], dtype='object')
# Index([2, 5, 8, 9], dtype='int64')
# (4, 3)

# %%
import numpy as np

# Semilla para reproducibilidad
np.random.seed(1)

# Listas de ejemplo
nombres = [
    "Ana", "Ana", "María", "Carlos", "Sofía", "Andrés", "Valentina", "Camilo", "Laura", "Jorge",
    "Diana", "Felipe", "Natalia", "Ricardo", "Daniela", "Sebastián", "Paula", "Juan", "Carolina", "Santiago",
    "Mónica", "Andrés F.", "Lorena", "José", "Tatiana", "Miguel", "Alejandra", "Cristian", "Manuela", "Ana"
]

# Generar columnas
edades = np.random.randint(17, 25, size=30)            # entre 17 y 24 años
semestres = np.random.randint(1, 10, size=30)          # entre 1 y 9 semestres
promedios = np.round(np.random.uniform(2.5, 5.0, 30), 2)  # promedio entre 2.5 y 5.0
generos = np.random.choice(["F", "M"], size=30)        # femenino o masculino

# Crear DataFrame
df = pd.DataFrame({
    "Nombre": nombres,
    "Edad": edades,
    "Semestres": semestres,
    "Promedio": promedios,
    "Género": generos
})

# Mostrar primeras filas
df.head(2)
# Out:
#   Nombre  Edad  Semestres  Promedio Género
# 0    Ana    22          3      4.97      M
# 1    Ana    20          5      4.37      M

# %%
# Columnas y filas
print(df.columns)
print(df.index)
print(df.shape)
# Out:
# Index(['Nombre', 'Edad', 'Semestres', 'Promedio', 'Género'], dtype='object')
# RangeIndex(start=0, stop=30, step=1)
# (30, 5)

# %% [markdown]
# ### 4. Exploración rápida de un DataFrame
# Estos métodos te permiten obtener una visión general del dataset.

# %%
df.tail(4)     # Últimas filas
# Out:
#        Nombre  Edad  Semestres  Promedio Género
# 26  Alejandra    19          5      4.16      F
# 27   Cristian    21          1      3.79      F
# 28    Manuela    22          4      4.86      F
# 29        Ana    23          3      3.97      F

# %%
df.info()      # Estructura general del DataFrame. Dato nulo == None
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     30 non-null     object
#  1   Edad       30 non-null     int64
#  2   Semestres  30 non-null     int64
#  3   Promedio   30 non-null     float64
#  4   Género     30 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
df.describe()  # Estadísticas de columnas numéricas
# Out:
#             Edad  Semestres   Promedio
# count  30.000000  30.000000  30.000000
# mean   20.666667   5.100000   3.636333
# std     2.122675   2.795933   0.710937
# min    17.000000   1.000000   2.550000
# 25%    19.000000   2.250000   3.062500
# 50%    21.000000   5.000000   3.675000
# 75%    22.000000   8.000000   4.190000
# max    24.000000   9.000000   4.970000

# %%
df.describe(include='object') # Estadísticas de columnas categoricas
# Out:
#        Nombre Género
# count      30     30
# unique     28      2
# top       Ana      F
# freq        3     17

# %%
df.describe(include='all')

# %% [markdown]
# ###  5. Selección de datos

# %%
df['Nombre']
df[['Nombre', 'Semestres']]
# Out:
#        Nombre  Semestres
# 0         Ana          3
# 1         Ana          5
# 2       María          8
# 3      Carlos          8
# 4       Sofía          2
# 5      Andrés          8
# 6   Valentina          1
# 7      Camilo          7
# 8       Laura          8
# 9       Jorge          7
# 10      Diana          2
# 11     Felipe          1
# 12    Natalia          2
# 13    Ricardo          9
# 14    Daniela          9
# 15  Sebastián          4
# 16      Paula          9
# 17       Juan          8
# 18   Carolina          4
# 19   Santiago          7
# 20     Mónica          6
# 21  Andrés F.          2
# 22     Lorena          4
# 23       José          5
# 24    Tatiana          9
# 25     Miguel          2
# 26  Alejandra          5
# 27   Cristian          1
# 28    Manuela          4
# 29        Ana          3

# %%
df
# Out:
#        Nombre  Edad  Semestres  Promedio Género
# 0         Ana    22          3      4.97      M
# 1         Ana    20          5      4.37      M
# 2       María    21          8      3.20      F
# 3      Carlos    17          8      4.47      M
# 4       Sofía    24          2      2.76      F
# 5      Andrés    18          8      3.62      M
# 6   Valentina    20          1      4.77      F
# 7      Camilo    22          7      3.23      F
# 8       Laura    24          8      3.22      F
# 9       Jorge    17          7      2.83      M
# 10      Diana    17          2      2.55      M
# 11     Felipe    18          1      4.20      M
# 12    Natalia    21          2      3.03      F
# 13    Ricardo    24          9      3.16      M
# 14    Daniela    22          9      3.73      F
# 15  Sebastián    21          4      2.63      F
# 16      Paula    23          9      3.94      F
# 17       Juan    18          8      2.87      F
# 18   Carolina    19          4      3.97      M
# ...

# %%
dff = pd.DataFrame({
    "Nombre": nombres,
    "Edad": edades,
    "Semestres": semestres,
    "Promedio": promedios,
    "Género": generos
}, index=[x for x in range(4,34)])
dff.head(4)
# Out:
#    Nombre  Edad  Semestres  Promedio Género
# 4     Ana    22          3      4.97      M
# 5     Ana    20          5      4.37      M
# 6   María    21          8      3.20      F
# 7  Carlos    17          8      4.47      M

# %%
#dff.loc[7]         # Fila por etiqueta (índice)
#df.iloc[3]        # Fila por indexación
dff.loc[5, 'Promedio'] # Elemento específico
# Out:
# np.float64(4.37)

# %%
df["Edad"].mean() # promedio de la edad
# Out:
# np.float64(20.666666666666668)

# %%
df['Género'].value_counts() # Contar categorias
# Out:
# Género
# F    17
# M    13
# Name: count, dtype: int64

# %%
df["Nombre"].nunique() #cantidad de valores únicos
# Out:
# 28

# %% [markdown]
# # Taller
#
# ## 📱  Uso de una Aplicación Tecnológica
#
# El siguiente conjunto de datos simula información recolectada de **100 usuarios** de una aplicación tecnológica (por ejemplo, una *app de aprendizaje en línea* o una *plataforma de productividad personal*).
# Los registros contienen variables demográficas y de comportamiento de uso, útiles para realizar análisis exploratorios, segmentación de usuarios y estudios de satisfacción.
#
# ---
#
# ### 🧾 Descripción general
# Cada fila del DataFrame representa un usuario único, e incluye información sobre:
# - Su edad y país de residencia.
# - Su nivel de interacción con la aplicación (tiempo y sesiones).
# - Su nivel de satisfacción reportado con la experiencia de uso.
#
# ---
#
# ### 📚 Diccionario de variables
#
# | Variable | Tipo de dato | Descripción |
# |-----------|---------------|-------------|
# | `Usuario` | *string* | Identificador único del usuario (ej. `user_001`) |
# | `Edad` | *int* | Edad del usuario en años |
# | `País` | *string* | País de residencia del usuario (ej. Colombia, México, España) |
# | `Tiempo_uso_min` | *int* | Tiempo promedio de uso diario de la aplicación (en minutos) |
# | `Sesiones_dia` | *int* | Número promedio de sesiones abiertas por día |
# | `Satisfacción` | *string* | Nivel de satisfacción del usuario con la aplicación (`Bajo`, `Medio`, `Alto`) |
#
# ---

# %%
import pandas as pd
import numpy as np

# Semilla para reproducibilidad
np.random.seed(123)

# Número de registros
n = 100

# Variables simuladas
usuarios = [f"user_{i:03d}" for i in range(1, n+1)]
edades = np.random.randint(18, 50, size=n)
pais = np.random.choice(["Colombia", "México", "Argentina", "Chile", "Perú", "España"], size=n)
tiempo_uso_min = np.random.randint(5, 240, size=n)              # minutos diarios de uso
sesiones = np.random.randint(1, 10, size=n)                     # sesiones por día
nivel_satisfaccion = np.random.choice(["Bajo", "Medio", "Alto"], size=n, p=[0.2, 0.5, 0.3])

# Crear DataFrame
df_app = pd.DataFrame({
    "Usuario": usuarios,
    "Edad": edades,
    "País": pais,
    "Tiempo_uso_min": tiempo_uso_min,
    "Sesiones_dia": sesiones,
    "Satisfacción": nivel_satisfaccion
})

# Mostrar primeras filas
df_app.head()
# Out:
#     Usuario  Edad       País  Tiempo_uso_min  Sesiones_dia Satisfacción
# 0  user_001    48     México             106             4        Medio
# 1  user_002    31       Perú             135             4        Medio
# 2  user_003    48  Argentina             151             2         Bajo
# 3  user_004    20     México              51             8         Alto
# 4  user_005    46     México              50             9        Medio

# %% [markdown]
# # Preguntas:
#
#
#
# 1. ¿Cuál es la edad promedio de todos los usuarios en el conjunto de datos?
#
# 2. ¿Cuál es la edad máxima y mínima registrada entre los usuarios?
#
# 3. ¿Cuántos usuarios hay por cada país?
#
# 4. ¿Cuántos usuarios son específicamente de Colombia?
#
# 5. ¿Cuántos usuarios hay en cada nivel de satisfacción (Bajo, Medio, Alto)?
#
# 6. ¿Cuántos minutos en total han usado la aplicación todos los usuarios?
#
# 7. ¿Cuál es el promedio de sesiones por día entre los usuarios? rta: 4.53
#
# 8. ¿Cuántos usuarios tienen menos sesiones al día que el promedio calculado? rta 53
